# %%
class demo:
    a=5
    _b=6
    __c=7

# %%
a=demo()

# %%
a.a
# Out:
# 5

# %%
a._b
# Out:
# 6

# %%
a.__c
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-588c5fac4ed4> in <module>
# ----> 1 a.__c
#
# AttributeError: 'demo' object has no attribute '__c'

# %%
a._demo__c
# Out:
# 7

# %%
help(property)
# Out:
# Help on class property in module builtins:
#
# class property(object)
#  |  property(fget=None, fset=None, fdel=None, doc=None)
#  |
#  |  Property attribute.
#  |
#  |    fget
#  |      function to be used for getting an attribute value
#  |    fset
#  |      function to be used for setting an attribute value
#  |    fdel
#  |      function to be used for del'ing an attribute
#  |    doc
#  |      docstring
#  |
#  |  Typical use is to define a managed attribute x:
#  |
#  |  class C(object):
#  |      def getx(self): return self._x
#  |      def setx(self, value): self._x = value
#  |      def delx(self): del self._x
#  |      x = property(getx, setx, delx, "I'm the 'x' property.")
#  |
#  |  Decorators make defining new properties or modifying existing ones easy:
#  |
#  |  class C(object):
#  |      @property
#  |      def x(self):
#  |          "I am the 'x' property."
#  |          return self._x
#  |      @x.setter
#  |      def x(self, value):
#  |          self._x = value
#  |      @x.deleter
#  |      def x(self):
#  |          del self._x
#  |
#  |  Methods defined here:
#  |
#  |  __delete__(self, instance, /)
#  |      Delete an attribute of instance.
#  |
#  |  __get__(self, instance, owner, /)
#  |      Return an attribute of instance, which is of type owner.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __set__(self, instance, value, /)
#  |      Set an attribute of instance to value.
#  |
#  |  deleter(...)
#  |      Descriptor to change the deleter on a property.
#  |
#  |  getter(...)
#  |      Descriptor to change the getter on a property.
#  |
#  |  setter(...)
#  |      Descriptor to change the setter on a property.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __isabstractmethod__
#  |
#  |  fdel
#  |
#  |  fget
#  |
#  |  fset

# %%
def add(a,b):
    return a+b
def add(a,b):
    return a-b

# %%
print(add(6,5))
# Out:
# 1

# %%
import builtins

# %%
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
#  'ReferenceError',
#  'ResourceWarning',
#  'RuntimeError',
#  'RuntimeWarning',
#  'StopAsyncIteration',
#  'StopIteration',
#  'SyntaxError',
#  'SyntaxWarning',
#  'SystemError',
#  'SystemExit',
#  'TabError',
#  'TimeoutError',
#  'True',
#  'TypeError',
#  'UnboundLocalError',
#  'UnicodeDecodeError',
#  'UnicodeEncodeError',
#  'UnicodeError',
#  'UnicodeTranslateError',
#  'UnicodeWarning',
#  'UserWarning',
#  'ValueError',
#  'Warning',
#  'WindowsError',
#  'ZeroDivisionError',
#  '__IPYTHON__',
#  '__build_class__',
#  '__debug__',
#  '__doc__',
#  '__import__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abs',
#  'all',
#  'any',
#  'ascii',
#  'bin',
#  'bool',
#  'breakpoint',
#  'bytearray',
#  'bytes',
#  'callable',
#  'chr',
#  'classmethod',
#  'compile',
#  'complex',
#  'copyright',
#  'credits',
#  'delattr',
#  'dict',
#  'dir',
#  'display',
#  'divmod',
#  'enumerate',
#  'eval',
#  'exec',
#  'filter',
#  'float',
#  'format',
#  'frozenset',
#  'get_ipython',
#  'getattr',
#  'globals',
#  'hasattr',
#  'hash',
#  'help',
#  'hex',
#  'id',
#  'input',
#  'int',
#  'isinstance',
#  'issubclass',
#  'iter',
#  'len',
#  'license',
#  'list',
#  'locals',
#  'map',
#  'max',
#  'memoryview',
#  'min',
#  'next',
#  'object',
#  'oct',
#  'open',
#  'ord',
#  'pow',
#  'print',
#  'property',
#  'range',
#  'repr',
#  'reversed',
#  'round',
#  'set',
#  'setattr',
#  'slice',
#  'sorted',
#  'staticmethod',
#  'str',
#  'sum',
#  'super',
#  'tuple',
#  'type',
#  'vars',
#  'zip']

# %%
temp =dir(builtins)

# %%
error=[]
for var in temp:
    if "Error" in var:
        error.append(var)

# %%
print(error)
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'EOFError', 'EnvironmentError', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'IOError', 'ImportError', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'NotADirectoryError', 'NotImplementedError', 'OSError', 'OverflowError', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'RuntimeError', 'SyntaxError', 'SystemError', 'TabError', 'TimeoutError', 'TypeError', 'UnboundLocalError', 'UnicodeDecodeError', 'UnicodeEncodeError', 'UnicodeError', 'UnicodeTranslateError', 'ValueError', 'WindowsError', 'ZeroDivisionError']

# %%
Exception?

# %%
import json
from time import sleep
import os
from getpass import getpass

def dec1():
    print(("*"*40).center(120))
    print("-ABCD Bank-")
    print(("*"*40).center(120))
    print("\n")

def dec():
    print("\n\n\n")
    print(("-."*240))

def clear():
    os.system("cls")
    dec()
    dec1()


def get_data():
    fp=open("G://Workspace/Python/Bank/data.db","r+")
    data=json.load(fp)
    fp.close()
    return data

def put_data(data):
    fp=open("G://Workspace/Python/Bank/data.db","w")
    json.dump(data,fp)
    fp.close()

def load():
    print("Loading",end='')
    for var in range(6):
        sleep(0.4)
        print('.',end='')


def banking():
    clear()
    print("\n\n-.-.-.-.-.-.-.-.-chose an option-.-.-.-.-.-.-.-.-".center(120))
    ch=int(input("\n1.Deposite\n2.Withdrawal\n3.Check Balance\n4.New a/c Open\n5.Edit information\n6.Manager Login\n"))
    if ch==1:
        load()
        deposite()
    elif ch==2:
        load()
        withdrawal()
    elif ch==3:
        load()
        chk_bal()
    elif ch==4:
        load()
        new_ac()
    elif ch==5:
        load()
        edit_info()
    elif ch==6:
        load()
        mgr()
    else:
        load()
        clear()
        print("\n\ninvalid option  Try Again".center(50,"*"))

def deposite():
    clear()
    acn=input("\nEnter Your Account Number:-")
    data=get_data()
    if acn not in data.keys():
        clear()
        print("acount number not available try again".center(50,"*"))
        deposite()
    amt=int(input("Enter amount to deposite:-"))
    data[acn]['bal']+=amt
    put_data(data)
    clear()
    print("\n\nTransaction successful".center(120,"*"))
    dec()

def withdrawal():
    clear()
    acn=input("\nEnter Your Account Number:-")
    data=get_data()
    if acn not in data.keys():
        clear()
        print("\nacount number not available please try again".center(120,"*"))
        withdrawal()
    usr_nm=input("Enter user name:-")
    paswd=getpass("Enter password:-")
    data=get_data()
    if usr_nm!=data[acn]['user'] or paswd!=data[acn]['password']:
        clear()
        print("Transaction Failed".center(120,"*"))
        print("username or password incorrect".center(120,"*"))
        dec()
        return
    amt=int(input("Enter amount to withdraw:-"))
    if amt>data[acn]['bal']:
        clear()
        print("insufficiant balance".center(120,"*"))
        dec()
        return
    data[acn]['bal']-=amt
    put_data(data)
    clear()
    print("transation successful".center(120,"*"))
    dec()

def chk_bal():
    clear()
    acn=input("Enter Your Account Number:-")
    data=get_data()
    if acn not in data.keys():
        clear()
        print("acount number not available please try again".center(50,"*"))
        chk_bal()
    clear()
    print(f"Acount number->{acn}\nholder\'s name->{data[acn]['fname']}\nAvailable balance->{data[acn]['bal']}")
    dec()

def new_ac():
    clear()
    fname=input("enter your first name:-")
    lname=input("enter your last name:-")
    mbn=int(input("enter your mobile numbre:-"))
    adrs=input("enter your permanent address:-")
    dob=input("enter your date of birth(yyyy-mm-dd):-")
    uname=input("enter your user name:-")
    password=getpass("enter your password:-")
    data=get_data()
    ky=data['key']
    data['key']+=1
    d={}
    d.setdefault("fname",fname);d.setdefault("lname",lname);d.setdefault("mobile",mbn)
    d.setdefault("address",adrs);d.setdefault("dob",dob);d.setdefault("user",uname)
    d.setdefault("password",password)
    d.setdefault("bal",0);d.setdefault("loan",0)
    data.setdefault(str(ky),d)
    put_data(data)
    clear()
    print("New account created".center(120,"*"))
    dec()

def edit_info():
    clear()
    acn=input("Enter Your Account Number:-")
    data=get_data()
    if acn not in data.keys():
        clear()
        print("acount number not available please try again".center(50,"*"))
        edit_info()
    print("-.-.-.-.-.-.-.-.-What you want to edit-.-.-.-.-.-.-.-.-")
    ch=int(input("1.fname\n2.lname\n3.mobilenumber\n4.password\n5.address\n"))
    clear()
    if ch==1:
        x=input("enter new first name:-")
        data[acn]['fname']=x
    elif ch==2:
        x=input("enter new last name:-")
        data[acn]['lname']=x
    elif ch==3:
        x=input("enter new mobile number:-")
        data[acn]['mobile']=x
    elif ch==4:
        x=input("enter new password:-")
        data[acn]['password']=x
    elif ch==5:
        x=input("enter new address:-")
        data[acn]['address']=x
    else:
        print("invalid option".center(120,"*"))
    put_data(data)
    clear()
    print("Change Successful".center(120,"*"))
    dec()

def mgr():
    clear()
    usr_nm=input("Enter user name:-")
    paswd=getpass("Enter password:-")
    data=get_data()
    if usr_nm!=data['mgr']['user'] or paswd!=data['mgr']['pass']:
        clear()
        print("Transaction Failed".center(120,"*"))
        print("username or password incorrect".center(120,"*"))
        return
    acn=input("enter account number to see details:-")
    while acn not in data.keys():
        acn=input("enter account number to see details:-")
        clear()
        print("acount number not available please try again".center(120,"*"))
    clear()
    print("details of given account number".center(50,"*"))
    print(f"account number->{acn}\nfirst name->{data[acn]['fname']}\nlast name->{data[acn]['lname']}\nmobile number->{data[acn]['mobile']}")
    print(f"address->{data[acn]['address']}\nAvailable balance->{data[acn]['bal']}\ngranted loan->{data[acn]['loan']}")
    dec()

# %%
opt=int(input("-.-.-.-.-.-.-.-.chose option.-.-.-.-.-.-.-.-.-\n1.banking\n2.Loan"))
if opt==1:
    load()
    banking()
elif opt==2:
    load()
    loan()
else:
    print("invalid option".center(50,"*"))
# Out:
# -.-.-.-.-.-.-.-.chose option.-.-.-.-.-.-.-.-.-
# 1.banking
# 2.Loan1
# Loading......
#
#
#
# -.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.
#                                         ****************************************
# -ABCD Bank-
#                                         ****************************************
#
#
#
#
# -.-.-.-.-.-.-.-.-chose an option-.-.-.-.-.-.-.-.-
#
# 1.Deposite
# 2.Withdrawal
# 3.Check Balance
# 4.New a/c Open
# 5.Edit information
# 6.Manager Login
# 1
# Loading......
#
#
#
# -.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.
#                                         ****************************************
# -ABCD Bank-
#                                         ****************************************
#
#
#
# Enter Your Account Number:-123
#
#
#
#
# -.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.
#                                         ****************************************
# -ABCD Bank-
#                                         ****************************************
#
#
# ******acount number not available try again*******
#
#
#
#
# -.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.
#                                         ****************************************
# -ABCD Bank-
#                                         ****************************************
#
#
#
# Enter Your Account Number:-12346
# Enter amount to deposite:-123
#
#
#
#
# -.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.
#                                         ****************************************
# -ABCD Bank-
#                                         ****************************************
#
#
# ************************************************
#
# Transaction successful************************************************
#
#
#
#
# -.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.-.
# Enter amount to deposite:-123
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-ec52db5c4947> in <module>
#       2 if opt==1:
#       3     load()
# ----> 4     banking()
#       5 elif opt==2:
#       6     load()
#
# <ipython-input-1-642949e9c89d> in banking()
#      44     if ch==1:
#      45         load()
# ---> 46         deposite()
#      47     elif ch==2:
#      48         load()
#
# <ipython-input-1-642949e9c89d> in deposite()
#      74         deposite()
#      75     amt=int(input("Enter amount to deposite:-"))
# ---> 76     data[acn]['bal']+=amt
#      77     put_data(data)
#      78     clear()
#
# KeyError: '123'

# %%
data={1001:{"name":input("enter your name"),"age":int(input("enter your age"))}}
# Out:
# enter your name12334
# enter your age23213

# %%
i=1
while i==1:
        try:
            amt=int(input("Enter amount to withdraw:-"))
            if amt>data[acn]['bal']:
                print("insufficiant balance".center(120,"*"))
                load()
            elif amt<0:
                print("--Amount can not be negative try again--")
            else:
                i=0
        except ValueError:
            print("*-* invalid amount try again *-*")
# Out:
# Enter amount to withdraw:-60000
# **************************************************insufficiant balance**************************************************
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8d36fab5b6cb> in <module>
#       5             if amt>50000:
#       6                 print("insufficiant balance".center(120,"*"))
# ----> 7                 load()
#       8             elif amt<0:
#       9                 print("--Amount can not be negative try again--")
#
# NameError: name 'load' is not defined
